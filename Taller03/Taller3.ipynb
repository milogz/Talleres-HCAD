# %%
# Initialize Otter
import otter
grader = otter.Notebook("Taller3.ipynb")

# %% [markdown]
# # Taller 3: Funciones
#
# En este taller practicarás la implementación de funciones y funciones anónimas (lambda) en Python.

# %% [markdown]
# ### Ejercicio 1
#
# A continuación encuentras una lista de números. Implementa una función llamada `suma_lista` que reciba por parámetro una lista de números (por ejemplo, la variable `lista`) y retorne la suma de todos sus elementos.
#
# *Esta función debe retornar un número.*

# %%
# No modifiques esta celda
lista = [20, 12, 21.3, 34]

# %%
# Escribe tu codigo aqui
...

# %%
grader.check("q1")

# %% [markdown]
# ### Ejercicio 2
#
# A continuación encuentras una lista de números y letras. Implementa una función llamada `primera_letra` que reciba una lista de números y letras por parámetro (por ejemplo, la variable `lista`) y retorne el primer elemento que sea una letra. La función debe retornar una cadena de texto vacía (`""`) si no encuentra una letra.
#
# *Esta función debe retornar una letra.*

# %%
# No modifiques esta celda
lista = [23, "2", 46 , "l", 8.3, "m"]

# %%
# Escribe tu codigo aqui
...

# %%
grader.check("q2")

# %% [markdown]
# ### Ejercicio 3
#
# A continuación encuentras una lista de números enteros. Implementa una función llamada `separar_pares_impares` que reciba una lista de números enteros por parámetro (por ejemplo, la variable `lista`) y retorne una tupla que contenga dos listas, cada una ordenada ascendentemente:
#
# * La primera lista debe contener los números pares.
# * La segunda lista debe contener los números impares.
#
# *Esta función debe retornar una tupla de listas.*

# %%
# No modifiques esta celda
lista = [4, 3, 8, 5, 6, 2, 7, 5]

# %%
# Escribe tu codigo aqui
...

# %%
grader.check("q3")

# %% [markdown]
# ### Ejercicio 4
#
# A continuación encuentras unos números enteros. Implementa una función anónima que reciba un número entero por parámetro (por ejemplo, la variable `treinta`) y retorne `True` si el número es mayor a 50. Guarda la función (sin ejecutar) en una variable llamada `mayor_a_cincuenta`.
#
# *Esta función debe retornar un valor booleano (`True` o `False`).*

# %%
# No modifiques esta celda
treinta = 30
cuarenta_y_cinco = 45
cincuenta = 50
sesenta_y_tres = 63

# %%
# Escribe tu codigo aqui
...

# %%
grader.check("q4")

# %% [markdown]
# ### Ejercicio 5
#
# A continuación encuentras una lista de números enteros. Implementa una función llamada `modulo_del_minimo` que reciba una lista de números enteros por parámetro (por ejemplo, la variable `lista`), encuentre el valor más pequeño que se repita en la lista (`min_val_rep`) y retorne una función anónima. Esta función anónima debe recibir un número entero mayor a cero (`entero`) por parámetro y retornar el residuo de la división entre `min_val_rep` y `entero` (recomendamos usar el operador de residuo `%`).
#
# *Esta función debe retornar una función anónima.*
#
# ##### Ejemplo
# ```python
# anon = modulo_del_minimo([3, 4, 2, 5, 5, 6, 3])
# anon(2) == 1
# ```

# %%
# No modifiques esta celda
lista = [3, 4, 2, 5, 5, 6, 3]

# %%
# Escribe tu codigo aqui
...

# %%
grader.check("q5")

# %% [markdown]
# ## Entrega
#
# Asegurate de haber ejecutado todas las celdas de tu notebook en orden antes de ejecutar la celda de abajo. La celda generara un archivo ZIP para que lo entregues. **Guarda tu notebook antes de exportar.**

# %%
# Guarda tu notebook y ejecuta esta celda para exportar tu entrega.
grader.export(pdf=False, run_tests=True)
