# %%
# Initialize Otter
import otter
grader = otter.Notebook("Taller7.ipynb")

# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
# No modifiques esta celda
orden_cliente = pd.DataFrame({'id_cliente': [1, 2, 3], 'monto': [100, 200, 300]})
cliente_categoria = pd.DataFrame({'id_cliente': [2, 3, 4], 'categoria': ['A', 'B', 'C']})

# %%
def union_derecha(df1, df2):
    ...
...

# %%
grader.check("q1")

# %%
# No modifiques esta celda
cliente_categoria_orden = pd.DataFrame({'id': [1,2], 'val': [3,4]})

# %%
def concatenar_interno(df1, df2):
    ...
...

# %%
grader.check("q2")

# %%
# No modifiques esta celda
ventas = pd.DataFrame({'A': [1, np.nan, 3]})

# %%
def mediana_faltantes(df):
    ...
...

# %%
grader.check("q3")

# %%
# No modifiques esta celda
clientes = pd.DataFrame({'Sexo': ['Masculino', 'Femenino', 'Femenino'], 'Cliente Premium': ['Si', 'No', 'No']})

# %%
def cliente_dummies(df):
    ...
...

# %%
grader.check("q4")

# %%
# No modifiques esta celda
fecha_string = '2020-10-December'

# %%
def cadena_a_fecha(cadena):
    ...
...

# %%
grader.check("q5")

# %%
def union_izquierda():
    ...
...

# %%
grader.check("q6")

# %%
# No modifiques esta celda
df = pd.DataFrame({'no_orden': [1, np.nan, np.nan], 'idVendedor': [np.nan, 2, np.nan], 'otro': [1, 2, 3]})

# %%
def ejercicio7(df):
    ...
...

# %%
grader.check("q7")

# %%
def ejercicio8():
    ...
...

# %%
grader.check("q8")

# %% [markdown]
# ## Entrega
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Asegurate de haber ejecutado todas las celdas...

# %%
# Guarda tu notebook y ejecuta esta celda para exportar tu entrega.
grader.export(pdf=False, run_tests=True)
