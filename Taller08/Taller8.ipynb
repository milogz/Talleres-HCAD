# %%
# Initialize Otter
import otter
grader = otter.Notebook("Taller8.ipynb")

# %% [markdown]
# # Taller 8: Visualización e Interactividad
#
# En este taller crearás gráficos interactivos usando `plotly` e `ipywidgets`.

# %%
# No modifiques esta celda
import plotly.graph_objects as go
import ipywidgets as widgets
import pandas as pd
from ipywidgets import interactive
import numpy as np

# %% [markdown]
# ### Ejercicio 1
#
# Utiliza `plotly` para realizar un diagrama de torta (`go.Pie`) sobre el estado conyugal (`Marital_Status`) de los clientes de la base de datos `BankChurners.csv`. Resalta la categoría más predominante usando el parámetro `pull`.
#
# Guarda tu gráfico en una variable llamada `fig`.

# %%
# No modifiques esta celda
df = pd.read_csv('Archivos/BankChurners.csv')

# %%
# Escribe tu codigo aqui
fig = ...
...

# %%
grader.check("q1")

# %% [markdown]
# ### Ejercicio 2
#
# Utiliza `plotly` para realizar un histograma (`go.Histogram`) que permita verificar si el cambio en el monto de transacciones (`Total_Amt_Chng_Q4_Q1`) se ajusta a una distribución normal.
#
# Guarda tu gráfico en una variable llamada `fig`.

# %%
# Escribe tu codigo aqui
fig = ...
...

# %%
grader.check("q2")

# %% [markdown]
# ### Ejercicio 3
#
# Utiliza `plotly` para realizar un gráfico de dispersión (`go.Scatter` con `mode='markers'`) que permita visualizar la relación entre las variables `Year_Birth` y `MntWines` de la base de datos de mercadeo.
#
# Guarda tu gráfico en una variable llamada `fig`.

# %%
# No modifiques esta celda
mercadeo = pd.read_csv('Archivos/marketing_data.csv')

# %%
# Escribe tu codigo aqui
fig = ...
...

# %%
grader.check("q3")

# %% [markdown]
# ### Ejercicio 4
#
# Utiliza `ipywidgets` para filtrar las observaciones de la base de datos de mercadeo de acuerdo con los siguientes criterios:
# 1. Nivel máximo de escolaridad alcanzado (`Education`).
# 2. Número de niños en el hogar (`Kidhome`).
# 3. Número de adolescentes en el hogar (`Teenhome`).
#
# Crea una función llamada `filtrar` y un widget interactivo llamado `interactive_plot`.

# %%
# Escribe tu codigo aqui
def filtrar(Escolaridad, Ninos, Adolescentes):
    ...

interactive_plot = ...
...

# %%
grader.check("q4")

# %% [markdown]
# ### Ejercicio 5
#
# Utiliza `ipywidgets` y `plotly` para generar un gráfico con controles que:
# 1. Cuente con un control desplegable para seleccionar una de las variables de gastos frente a los ingresos.
# 2. Genere un gráfico de dispersión de la variable seleccionada vs `Income`.
# 3. Genere un diagrama de caja de la variable seleccionada.
#
# Variables de gastos: `MntWines`, `MntFruits`, `MntMeatProducts`, `MntFishProducts`, `MntSweetProducts`, `MntGoldProds`.
#
# Crea una función llamada `generar_graficos` y un widget llamado `control_gastos`.

# %%
# Escribe tu codigo aqui
def generar_graficos(variable_gasto='MntWines'):
    ...

control_gastos = ...
...

# %%
grader.check("q5")

# %% [markdown]
# ## Entrega
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Asegurate de haber ejecutado todas las celdas de tu notebook antes de exportar.

# %%
# Guarda tu notebook y ejecuta esta celda para exportar tu entrega.
grader.export(pdf=False, run_tests=True)
