# %%
# Initialize Otter
import otter
grader = otter.Notebook("Taller10.ipynb")

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle

# %% [markdown]
# ## Pregunta 1

# %%
archivo = pd.read_excel('Archivos/datosTaller.xlsx')

# %%
def dividir_datos(df):
    ...
...

# %%
grader.check("q1")

# %% [markdown]
# ## Pregunta 2

# %%
datos = (X, y)

# %%
def crear_train_test(datos):
    ...
...

# %%
grader.check("q2")

# %% [markdown]
# ## Pregunta 3

# %%
datos = (X_tr, X_te, y_tr, y_te)

# %%
def crear_modelo(datos):
    ...
...

# %%
grader.check("q3")

# %% [markdown]
# ## Pregunta 4

# %%
with open('Archivos/modeloTaller', 'rb') as f:
    modelo = pickle.load(f)

# %%
def predecir(modelo, datos):
    ...
...

# %%
grader.check("q4")

# %% [markdown]
# ## Pregunta 5

# %%
def calcular_precision(modelo, X_test, y_test):
    ...
...

# %%
grader.check("q5")

# %% [markdown]
# ## Entrega
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Asegúrate de haber ejecutado todas las celdas y que el output se muestre correctamente antes de exportar el notebook como pdf y entregarlo en Bloque Neón.

# %%
# Guarda tu notebook y ejecuta esta celda para exportar tu entrega.
grader.export(pdf=False, run_tests=True)
