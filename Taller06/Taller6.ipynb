# %%
# Initialize Otter
import otter
grader = otter.Notebook("Taller6.ipynb")

# %% [markdown]
# # Taller 6: Explorar y modificar bases de datos utilizando `pandas`
#
# En este taller filtrarás y modificarás bases de datos por medio de sus índices al resolver diversos ejercicios.

# %% [markdown]
# ## Instrucciones
#
# En cada uno de los siguientes ejercicios deberás implementar la función solicitada. La calificación se realiza de manera automática.

# %%
# No modifiques esta celda
import numpy as np
import pandas as pd
import inspect

# %% [markdown]
# ### Ejercicio 1
#
# Junto a este Notebook encontrarás un archivo llamado `"pooled_data_public.dta"` que contiene los resultados de la encuesta de hogares.
#
# Implementa una función llamada `importar_e_indexar` que no reciba parámetros, importe los datos del archivo `"Archivos/pooled_data_public.dta"` en un `DataFrame`, establezca la columna `"id"` como el índice del `DataFrame` y lo retorne.
#
# *Esta función debe retornar un `DataFrame` de 230509 filas y 128 columnas.*

# %%
def importar_e_indexar():
    # Escribe tu codigo aqui
    ...
...

# %%
grader.check("q1")

# %% [markdown]
# ### Ejercicio 2
#
# Implementa una función llamada `indice_sencillo_a_multiple` que no reciba parámetros, tome el `DataFrame` resultante de la función `importar_e_indexar` y cambie el índice de uno sencillo a uno múltiple al agregar la columna `"country_code"` al índice existente.
#
# *Esta función debe retornar un `DataFrame` con un `MultiIndex` de 230509 filas y 127 columnas.*

# %%
def indice_sencillo_a_multiple():
    # Escribe tu codigo aqui
    ...
...

# %%
grader.check("q2")

# %% [markdown]
# ### Ejercicio 3
#
# Implementa una función llamada `sin_columnas` que no reciba parámetros, tome el `DataFrame` resultante de la función `importar_e_indexar` y elimine las columnas `"country_name"`, `"grado"` y `"coima"` del `DataFrame`. Utiliza el método `.drop()`.
#
# *Esta función debe retornar un `DataFrame` de 230509 filas y 125 columnas.*

# %%
def sin_columnas():
    # Escribe tu codigo aqui
    ...
...

# %%
grader.check("q3")

# %% [markdown]
# ### Ejercicio 4
#
# Implementa una función llamada `indexar_columnas_numericamente` que no reciba parámetros, tome el `DataFrame` resultante de la función `importar_e_indexar` y elimine las columnas que se encuentran en las posiciones 80 a 100 (incluyendo la posición 100).
#
# *Esta función debe retornar un `DataFrame` de 230509 filas y 107 columnas.*

# %%
def indexar_columnas_numericamente():
    # Escribe tu codigo aqui
    ...
...

# %%
grader.check("q4")

# %% [markdown]
# ### Ejercicio 5
#
# A raíz de la pandemia, los gobiernos de latinoamérica desean monitorear a aquellas personas que trabajan fuera de su casa y que tienen adultos mayores en su hogar.
#
# Implementa una función llamada `trabajo_afuera_y_mayores` que no reciba parámetros, tome el `DataFrame` resultante de la función `importar_e_indexar` y filtre aquellas personas que trabajan fuera de su casa (`trabajocasa == "Fuera de su casa"`) y que tienen adultos mayores en su hogar (`haymayores == "si"`).
#
# *Esta función debe retornar un `DataFrame` de 14311 filas.*

# %%
def trabajo_afuera_y_mayores():
    # Escribe tu codigo aqui
    ...
...

# %%
grader.check("q5")

# %% [markdown]
# ### Ejercicio 6
#
# Implementa una función llamada `hogares_decrecen` que no reciba parámetros, tome el `DataFrame` resultante de la función `importar_e_indexar` y filtre aquellos hogares donde el número de personas en el hogar decreció durante la pandemia (`nrhogar_antes > nrhogar`).
#
# *Esta función debe retornar un `DataFrame`.*

# %%
def hogares_decrecen():
    # Escribe tu codigo aqui
    ...
...

# %%
grader.check("q6")

# %% [markdown]
# ## Entrega
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Asegurate de haber ejecutado todas las celdas de tu notebook antes de exportar.

# %%
# Guarda tu notebook y ejecuta esta celda para exportar tu entrega.
grader.export(pdf=False, run_tests=True)
