# %%
# Initialize Otter
import otter
grader = otter.Notebook("Taller4.ipynb")

# %% [markdown]
# # Taller 4 - Funciones, manejo de archivos y cadenas

# %% [markdown]
# ## Pregunta 1
# Sustituir caracteres.

# %%
cadena = 'Archivos de texto'

# %%
...

# %%
grader.check("q1")

# %% [markdown]
# ## Pregunta 2
# Leer archivo.

# %%
directorio = './Archivos/tesoro.txt'

# %%
...

# %%
grader.check("q2")

# %% [markdown]
# ## Pregunta 3
# Filtrar países.

# %%
lista_paises = ['Japón', 'Francia']
lineas = archivo_a_lista('./Archivos/tesoro.txt')

# %%
...

# %%
grader.check("q3")

# %% [markdown]
# ## Pregunta 4
# ECM.

# %%
pronostico_jorge = ['A', 'B']
pronostico_juan = ['B', 'A']

# %%
...

# %%
grader.check("q4")

# %% [markdown]
# ## Entrega
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Asegurate de haber ejecutado todas las celdas...

# %%
# Guarda tu notebook y ejecuta esta celda para exportar tu entrega.
grader.export(pdf=False, run_tests=True)
