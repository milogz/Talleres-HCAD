# %%
# Initialize Otter
import otter
grader = otter.Notebook("Taller5.ipynb")

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Ejercicio 1

# %%
mercadeo = np.array([2000, 1500, 1300, 1600])
logistica = np.array([1800, 1600, 1200, 1600])

# %%
...

# %%
grader.check("q1")

# %% [markdown]
# ## Ejercicio 2

# %%
hermanos = pd.Series({'Juan': 45, 'Maria': 42, 'Pedro': 47, 'Ana': 39})

# %%
...

# %%
grader.check("q2")

# %% [markdown]
# ## Contexto para Ejercicios 3, 4 y 5

# %%
empleados_data = {'Ciudad Residencia': ['Bogota', 'Medellin', 'Cali', 'Bogota', 'Barranquilla'], 'Salario (en USD)': [1200, 1100, 1050, 1500, 1300]}
empleados = pd.DataFrame(empleados_data, index=['Juan', 'Maria', 'Pedro', 'Ana', 'Luis'])

# %%
...

# %%
grader.check("q3")

# %%
...

# %%
grader.check("q4")

# %%
...

# %%
grader.check("q5")

# %% [markdown]
# ## Contexto para Ejercicios 6, 7 y 8

# %%
paises = pd.read_csv('./Archivos/DiccionarioPaises.csv', encoding='UTF-8', delimiter=';')
alfabeto = ('A','B','C','D','E','F','G','H','I','J','K','L','M','N','Ñ','O','P','Q','R','S','T','U','V','W','X','Y','Z')

# %%
...

# %%
grader.check("q6")

# %%
...

# %%
grader.check("q7")

# %%
...

# %%
grader.check("q8")

# %% [markdown]
# ## Entrega
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Asegurate de haber ejecutado todas las celdas...

# %%
# Guarda tu notebook y ejecuta esta celda para exportar tu entrega.
grader.export(pdf=False, run_tests=True)
