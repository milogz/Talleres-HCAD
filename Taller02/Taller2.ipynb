# %%
# Initialize Otter
import otter
grader = otter.Notebook("Taller2.ipynb")

# %% [markdown]
# # Taller 2: Estructuras de control: condicionales y ciclos

# %% [markdown]
# Pregunta 1. Mayor de dos números. Variables: num_1=2, num_2=3. Encuentra el mayor.

# %%
num_1 = 2
num_2 = 3
# No modifiques esta celda

# %%
mayor = ...
...

# %%
grader.check("q1")

# %% [markdown]
# Pregunta 2. Elemento en lista. Variables: elemento='e', lista=['b','c','a','d']. Agrega si no está.

# %%
elemento = 'e'
lista = ['b','c','a','d']
# No modifiques esta celda

# %%
# Escribe tu código aquí
...
...

# %%
grader.check("q2")

# %% [markdown]
# Pregunta 3. División o residuo. Variables: num=7, divisor=3.

# %%
num = 7
divisor = 3
# No modifiques esta celda

# %%
division_o_residuo = ...
...

# %%
grader.check("q3")

# %% [markdown]
# Pregunta 4. Corredor más rápido.

# %%
vel_Camilo=10.5
vel_Esteban=9.3
vel_Alejandro=9.8
vel_David=10.2
# No modifiques esta celda

# %%
mas_rapido = ...
...

# %%
grader.check("q4")

# %% [markdown]
# Pregunta 5. Ocupación de un teatro.

# %%
num_actual=20
cap_maxima=45
# No modifiques esta celda

# %%
info = ...
...

# %%
grader.check("q5")

# %% [markdown]
# Pregunta 6. Tipo de pizza.

# %%
vegetarianos=['Tomate','Champiñones','Cebolla']
no_vegetarianos=['Pepperoni','Pollo','Jamón']
ingrediente_1='Champiñones'
ingrediente_2='Pollo'
ingrediente_3='Cebolla'
# No modifiques esta celda

# %%
tipo = ...
...

# %%
grader.check("q6")

# %% [markdown]
# Pregunta 7. Números pares.

# %%
n=100
# No modifiques esta celda

# %%
pares = ...
...

# %%
grader.check("q7")

# %% [markdown]
# Pregunta 8. Cuenta regresiva.

# %%
inicio=10
# No modifiques esta celda

# %%
cuenta_regresiva = ...
...

# %%
grader.check("q8")

# %% [markdown]
# Pregunta 9. Búsqueda de índice.

# %%
numeros=[1,2,8,4,89,3,89]
a_buscar=89
# No modifiques esta celda

# %%
indice = ...
...

# %%
grader.check("q9")

# %% [markdown]
# Pregunta 10. Conteo de vocales.

# %%
cadena='Me encanta programar en Python'
# No modifiques esta celda

# %%
num_vocales = ...
...

# %%
grader.check("q10")

# %% [markdown]
# Pregunta 11. Perros para evento.

# %%
lb=2
ub=5
perros_refugio={'Max':1,'Bella':4,'Charlie':6,'Luna':3,'Rocky':5}
# No modifiques esta celda

# %%
perros_evento = ...
...

# %%
grader.check("q11")

# %% [markdown]
# Pregunta 12. Descifrar mensaje.

# %%
cifrada='Aqxzxobjmp'
corr=3
alfabeto='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'
# No modifiques esta celda

# %%
descifrada = ...
...

# %%
grader.check("q12")

# %% [markdown]
# Pregunta 13. Elección de regalo.

# %%
catalogo={'Libro': 50000, 'Juego': 120000, 'Audífonos': 80000}
presupuesto=100000
# No modifiques esta celda

# %%
regalo = ...
...

# %%
grader.check("q13")

# %% [markdown]
# ## Entrega
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Asegúrate de haber ejecutado todas las celdas...

# %%
# Guarda tu notebook y ejecuta esta celda para exportar tu entrega.
grader.export(pdf=False, run_tests=True)
