# %%
# Initialize Otter
import otter
grader = otter.Notebook("Taller9.ipynb")

# %% [markdown]
# # Taller 9: Dashboard interactivo de COVID-19
#
# En este taller construirás un dashboard interactivo usando `panel` y `plotly` con datos de COVID-19 de la OMS.

# %%
# No modifiques esta celda
import panel as pn
import plotly.graph_objects as go
import pandas as pd
pn.extension('plotly')

# %% [markdown]
# ## Diccionario de datos
#
# El archivo `Archivos/COVID-19.csv` contiene las siguientes variables:
# - `Name`: Nombre del país
# - `WHO Region`: Región de la OMS
# - `Cases - cumulative total`: Total de casos acumulados
# - `Cases - cumulative total per 1 million population`: Casos acumulados por millón
# - `Cases - newly reported in last 7 days`: Casos nuevos últimos 7 días
# - `Cases - newly reported in last 24 hours`: Casos nuevos últimas 24 horas
# - `Deaths - cumulative total`: Total de muertes acumuladas
# - `Deaths - cumulative total per 1 million population`: Muertes por millón
# - `Deaths - newly reported in last 7 days`: Muertes últimos 7 días
# - `Deaths - newly reported in last 24 hours`: Muertes últimas 24 horas

# %% [markdown]
# ### Paso 1: Cargar los datos
#
# Carga el archivo `Archivos/COVID-19.csv` en un DataFrame llamado `datos`.

# %%
datos = ...
...

# %%
grader.check("q1")

# %% [markdown]
# ### Paso 2: Control de tipo
#
# Crea un widget `RadioButtonGroup` llamado `criterio_tipo` con opciones `['Casos', 'Muertes']`.

# %%
criterio_tipo = ...
...

# %%
grader.check("q2")

# %% [markdown]
# ### Paso 3: Control de periodo
#
# Crea un widget `RadioButtonGroup` llamado `criterio_periodo` con opciones `['Historico', 'Ultimos 7 dias', 'Ultimas 24 horas']`.

# %%
criterio_periodo = ...
...

# %%
grader.check("q3")

# %% [markdown]
# ### Paso 4: Gráfico interactivo
#
# Crea una función llamada `funcion_interactiva` decorada con `@pn.depends` que reciba la selección de tipo y periodo, y retorne un diagrama de barras horizontal (`go.Bar` con `orientation='h'`) mostrando los 10 países con mayor valor.

# %%
# Escribe tu codigo aqui
...

# %%
grader.check("q4")

# %% [markdown]
# ### Paso 5: Muertes por millón
#
# Crea un diagrama de barras horizontal llamado `fig_muertes_millon` con los 10 países con mayor número de muertes por millón de personas.

# %%
fig_muertes_millon = ...
...

# %%
grader.check("q5")

# %% [markdown]
# ### Paso 6: Casos por región OMS
#
# Crea un diagrama de barras horizontal llamado `fig_regiones` con los casos acumulados agrupados por región de la OMS.

# %%
fig_regiones = ...
...

# %%
grader.check("q6")

# %% [markdown]
# ### Paso 7: Tablero de control
#
# Crea el tablero de control completo llamado `tablero_control` usando `pn.Column` y/o `pn.Row` que integre los widgets, el gráfico interactivo y los gráficos estáticos.

# %%
tablero_control = ...
...

# %%
grader.check("q7")

# %% [markdown]
# ## Entrega
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Asegurate de haber ejecutado todas las celdas de tu notebook antes de exportar.

# %%
# Guarda tu notebook y ejecuta esta celda para exportar tu entrega.
grader.export(pdf=False, run_tests=True)
